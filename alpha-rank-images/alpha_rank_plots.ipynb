# %%
import seaborn as sns
import pandas as pd
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
df = pd.read_csv('arank_conf.csv')

# %%
g = sns.lineplot(x="episodes M", y="Probability of alpha-rank estimated top strategy",
                data=df,)

# %% [markdown]
# Speed-confidence chart<br>
# If one predator is dominant(has top speed), the final confidence of estimated strategy is high.

# %%
dfs = pd.DataFrame([['[1.0,1.0,1.0]',0.11],['[0.8,1.0,1.2]',0.17],['[0.2,1.0,2.0]',0.33]],columns=['Speed','Confidence'])

# %%
dfs.to_csv('speed_conf.csv')

# %%
g = sns.lineplot(x="Speed", y="Confidence",
                data=dfs,)
